# %%
# !nvdia-smi
# Out:
# /bin/bash: line 1: nvdia-smi: command not found

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.2/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/yv8fdataset
# Out:
# /content/drive/MyDrive/yv8fdataset

# %%
# !ls
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  train  valid

# %%
#%cd /content/drive/MyDrive/archive (5)

# !yolo task=detect mode=train model=yolov8s.pt data= /content/drive/MyDrive/yv8fdataset/data.yaml epochs=25 imgsz=416 plots=True
# Out:
# Ultralytics YOLOv8.0.226 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !ls runs/detect/train2/
# Out:
# args.yaml					    PR_curve.png	train_batch1.jpg
# confusion_matrix_normalized.png			    R_curve.png		train_batch2.jpg
# confusion_matrix.png				    results.csv		val_batch0_labels.jpg
# events.out.tfevents.1702320123.8ebfea2521c6.2904.0  results.png		val_batch0_pred.jpg
# F1_curve.png					    train_batch0.jpg	val_batch1_labels.jpg
# labels_correlogram.jpg				    train_batch150.jpg	val_batch1_pred.jpg
# labels.jpg					    train_batch151.jpg	weights
# P_curve.png					    train_batch152.jpg

# %%
import cv2
import math
from ultralytics import YOLO

# Load the YOLO model
model = YOLO('/content/drive/MyDrive/best (1).pt')

# Load the uploaded image
image_path = '/content/Datacluster-Fire-and-Smoke-Sample--11-_jpg.rf.52b51dc1a0c390359afd0e5522faa7e1.jpg'  # Replace with the name of your uploaded photo
frame = cv2.imread(image_path)

# Reading the classes
classnames = ['fire']

result = model(frame)

# Getting bbox, confidence, and class names information to work with
for info in result:
    boxes = info.boxes
    for box in boxes:
        confidence = box.conf[0]
        confidence = math.ceil(confidence * 100)
        Class = int(box.cls[0])
        if confidence > 50:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 5)
            text = f'{classnames[Class]} {confidence}%'
            cv2.putText(frame, text, (x1 + 8, y1 + 100), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (255, 255, 255), 2)

# # Display the result
# cv2.imshow('image', frame)
# cv2.waitKey(0)  # Wait for a key press to close the image window

from matplotlib import pyplot as plt
import cv2

# Assuming 'frame' is your image
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Turn off axis labels
plt.show()
# Out:
# 0: 416x416 1 fire-smoke, 10.1ms
# Speed: 1.1ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 416)

# %%
##image(filename='/content/drive/MyDrive/yv8fdataset/runs/detect/train2/confusion_matrix.png', width=600)

# %%
##Image(filename='/content/drive/MyDrive/yv8fdataset/runs/detect/train2/results.png', width=600)

# %%
##Image(filename='/content/drive/MyDrive/yv8fdataset/runs/detect/train2/val_batch0_pred.jpg', width=600)

# %%
import cv2
import math
from ultralytics import YOLO
from matplotlib import pyplot as plt

# Load the YOLO model
model = YOLO('/content/drive/MyDrive/best (1).pt')

# Load the uploaded image
image_path = '/content/drive/MyDrive/yv8fdataset/train/images/Datacluster-Fire-and-Smoke-Sample--29-_jpg.rf.e5bb84d37221c43f1697d22104ca23d1.jpg'
frame = cv2.imread(image_path)

# Reading the classes
classnames = ['fire', 'smoke']

result = model(frame)

# Getting bbox, confidence, and class names information to work with
for info in result:
    boxes = info.boxes
    for box in boxes:
        confidence = box.conf[0]
        confidence = math.ceil(confidence * 100)
        Class = int(box.cls[0])
        if confidence > 50:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 5)
            text = f'{classnames[Class]} {confidence}%'
            cv2.putText(frame, text, (x1 + 8, y1 + 100), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (255, 255, 255), 2)

# Display the result using matplotlib
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.axis('off')  # Turn off axis labels
plt.show()
# Out:
# 0: 416x416 1 fire-smoke, 27.2ms
# Speed: 1.1ms preprocess, 27.2ms inference, 13.9ms postprocess per image at shape (1, 3, 416, 416)
